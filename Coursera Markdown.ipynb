# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Hrishikesh Nair**<br>
#     Data Scientist

# %% [markdown]
# *I am interested in data science as the study and interpretation of data intrigues me. The vast sea of data can be very usefull in understanding the world around us*

# %% [markdown]
# ### The below code will find if the the square of the number 5

# %%
x=5
print(x*x)
# Out:
# 25

# %% [markdown]
# ##### Do's for writing a code
# When writing a syntax for for loop<br>
# .  After for loop keep indentation<br>
# .  ~Write **for** at the end of the loop statement~<br>
# .  Keep a colon after the for statement<br>
# ----------------------------------------------------------<br>
# Eg <br>```for i in range(3):```<br>
#         &ensp;&ensp;&ensp;```x=x+i```<br>
#        ```print(x) ```
